# %%
# %lsmagic
# Out:
# Available line magics:
# %alias  %alias_magic  %autoawait  %autocall  %automagic  %autosave  %bookmark  %cd  %clear  %cls  %colors  %conda  %config  %connect_info  %copy  %ddir  %debug  %dhist  %dirs  %doctest_mode  %echo  %ed  %edit  %env  %gui  %hist  %history  %killbgscripts  %ldir  %less  %load  %load_ext  %loadpy  %logoff  %logon  %logstart  %logstate  %logstop  %ls  %lsmagic  %macro  %magic  %matplotlib  %mkdir  %more  %notebook  %page  %pastebin  %pdb  %pdef  %pdoc  %pfile  %pinfo  %pinfo2  %pip  %popd  %pprint  %precision  %prun  %psearch  %psource  %pushd  %pwd  %pycat  %pylab  %qtconsole  %quickref  %recall  %rehashx  %reload_ext  %ren  %rep  %rerun  %reset  %reset_selective  %rmdir  %run  %save  %sc  %set_env  %store  %sx  %system  %tb  %time  %timeit  %unalias  %unload_ext  %who  %who_ls  %whos  %xdel  %xmode
#
# Available cell magics:
# ...

# %%
# !pip install psycopg2

# %%
# !pip install ipython-sql
# Out:
# ...
#   Using cached ipython_sql-0.5.0-py3-none-any.whl (20 kB)
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.10.0.2
#     Uninstalling typing-extensions-3.10.0.2:
#       Successfully uninstalled typing-extensions-3.10.0.2
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.4.22
#     Uninstalling SQLAlchemy-1.4.22:
#       Successfully uninstalled SQLAlchemy-1.4.22
# ...

# %%
# !pip install ipython-sql psycopg2

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql postgresql://postgres:01656711@localhost:5432/NAM

# %%
# %sql SELECT * FROM employee
# Out:
#  * postgresql://postgres:***@localhost:5432/NAM
#    postgresql://postgres:***@localhost:5432/cohort_4
# 2 rows affected.
# [(1, 'Nam', 1656711), (2, 'Thinh', 165155431)]

# %%
# %sql SELECT * FROM benhnhan
# Out:
#  * postgresql://postgres:***@localhost:5432/NAM
#    postgresql://postgres:***@localhost:5432/cohort_4
# 14042 rows affected.
# [('sỏi đường mật', 'Bệnh Đường Tiêu Hóa'),
#  ('viêm đa xoang mt đợt cấp', 'Bệnh Tai Mũi Họng'),
#  ('hoại tử ngón iii chân (t)', 'Bệnh Cơ Xương Khớp'),
#  ('nhịp nhanh nhĩ đa ổ', 'Bệnh Tim Mạch'),
#  ('gãy hở lồi cầu xương cánh tay (t)', 'Bệnh Cơ Xương Khớp'),
#  ('thai 35 tuần', 'Bệnh Nhi & Sơ Sinh'),
#  ('viêm dạ dày xuất huyết tiêu hóa', 'Bệnh Đường Tiêu Hóa'),
#  ('hậu phẫu hạch cổ (p)', 'Bệnh Nội Tiết, Đái Tháo Đường'),
#  ('u xơ tử cung đã nút mạch', 'Bệnh Phụ Khoa'),
#  ('td k', 'Khác'),
#  ('đờ tử cung', 'Bệnh Phụ Khoa'),
#  ('vết thương hở cùng cụt', 'Bệnh Truyền Nhiễm'),
#  ('không xác định vi sinh vật [phế nhiệt chứng]', 'Bệnh Truyền Nhiễm'),
#  ('dập não chẩm', 'Bệnh Hệ Thần Kinh'),
#  ('tụ máu dưới màng cứng bán cầu trái do bị đánh', 'Bệnh Hệ Thần Kinh'),
#  ('dị ứng thức ăn không rõ loại', 'Bệnh Nội Tiết, Đái Tháo Đường'),
# ...

# %%
# %sql CREATE TABLE DiaPhuong (MaDP int primary key);
# Out:
#  * postgresql://postgres:***@localhost:5432/NAM
#    postgresql://postgres:***@localhost:5432/cohort_4
# (psycopg2.errors.DuplicateTable) relation "diaphuong" already exists
#
# [SQL: CREATE TABLE DiaPhuong (MaDP int primary key);]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %sql create table SinhVien (MaSV int primary key,TenSV nchar(50) not null,QueQuan int references DiaPhuong(MaDP))
# Out:
#  * postgresql://postgres:***@localhost:5432/NAM
#    postgresql://postgres:***@localhost:5432/cohort_4
# (psycopg2.errors.DuplicateTable) relation "sinhvien" already exists
#
# [SQL: create table SinhVien (MaSV int primary key,TenSV nchar(50) not null,QueQuan int references DiaPhuong(MaDP))]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# %sql ALTER TABLE SinhVien ALTER COLUMN TenSV SET DEFAULT 'khong ten';
# Out:
#  * postgresql://postgres:***@localhost:5432/NAM
#    postgresql://postgres:***@localhost:5432/cohort_4
# Done.
# []

# %%
# %sql SELECT * FROM Sinhvien
# Out:
#  * postgresql://postgres:***@localhost:5432/NAM
#    postgresql://postgres:***@localhost:5432/cohort_4
# 0 rows affected.
# []

# %%
# %sql alter table SinhVien add foreign key (QueQuan) references DiaPhuong(MaDP)
# Out:
#  * postgresql://postgres:***@localhost:5432/NAM
#    postgresql://postgres:***@localhost:5432/cohort_4
# Done.
# []

# %%
# %sql ALTER TABLE sinhvien ADD CONSTRAINT sinhvien_quequan_fkey FOREIGN KEY (quequan) REFERENCES diaphuong (MaDP);
# Out:
#  * postgresql://postgres:***@localhost:5432/NAM
#    postgresql://postgres:***@localhost:5432/cohort_4
# Done.
# []

# %%
# %sql insert into diaphuong(MaDP)values(1),(2),(3)
# Out:
#  * postgresql://postgres:***@localhost:5432/NAM
#    postgresql://postgres:***@localhost:5432/cohort_4
# 3 rows affected.
# []

# %%
# %sql DELETE FROM diaphuong WHERE MaDP=1;
# Out:
#  * postgresql://postgres:***@localhost:5432/NAM
#    postgresql://postgres:***@localhost:5432/cohort_4
# 0 rows affected.
# []

# %%
# %sql insert into SinhVien(MaSV, TenSV, QueQuan)values (1,'Nguyễn Văn A',1),(2, 'Tran Thi B', 2),(3, 'Le Van C', 3);
# Out:
#  * postgresql://postgres:***@localhost:5432/NAM
#    postgresql://postgres:***@localhost:5432/cohort_4
# 3 rows affected.
# []

# %%
# %sql select * FROM sinhvien
# Out:
#  * postgresql://postgres:***@localhost:5432/NAM
#    postgresql://postgres:***@localhost:5432/cohort_4
# 3 rows affected.
# [(1, 'Nguyễn Văn A                                      ', 1),
#  (2, 'Tran Thi B                                        ', 2),
#  (3, 'Le Van C                                          ', 3)]

# %%
# %sql truncate table SinhVien
# Out:
#  * postgresql://postgres:***@localhost:5432/NAM
#    postgresql://postgres:***@localhost:5432/cohort_4
# Done.
# []

# %%
# %sql update SinhVien SET NhomTruong = 1 where MaSV<2; #update theo dieukien
# Out:
#  * postgresql://postgres:***@localhost:5432/NAM
#    postgresql://postgres:***@localhost:5432/cohort_4
# 1 rows affected.
# []

# %%
# %sql alter table SinhVien add NhomTruong int
# Out:
#  * postgresql://postgres:***@localhost:5432/NAM
#    postgresql://postgres:***@localhost:5432/cohort_4
# Done.
# []

# %%
# %sql Select * FROM sinhvien
# Out:
#  * postgresql://postgres:***@localhost:5432/NAM
#    postgresql://postgres:***@localhost:5432/cohort_4
# 3 rows affected.
# [(2, 'Tran Thi B                                        ', 2, None),
#  (3, 'Le Van C                                          ', 3, None),
#  (1, 'Nguyễn Văn A                                      ', 1, 1)]

# %%
# %sql Select tenSV FROM sinhvien
# Out:
#  * postgresql://postgres:***@localhost:5432/NAM
#    postgresql://postgres:***@localhost:5432/cohort_4
# 3 rows affected.
# [('Tran Thi B                                        ',),
#  ('Le Van C                                          ',),
#  ('Nguyễn Văn A                                      ',)]

# %%
# %sql Select * FROM Sinhvien order by masv ASC; #Sắp xếp tăng dần
# Out:
#  * postgresql://postgres:***@localhost:5432/NAM
#    postgresql://postgres:***@localhost:5432/cohort_4
# 3 rows affected.
# [(1, 'Nguyễn Văn A                                      ', 1, 1),
#  (2, 'Tran Thi B                                        ', 2, None),
#  (3, 'Le Van C                                          ', 3, None)]
