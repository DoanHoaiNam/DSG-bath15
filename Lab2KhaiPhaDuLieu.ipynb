# %%
import pandas as pd
df1 = pd.read_csv("ThiTHPT2018.csv", index_col = 0)
df2 = pd.read_excel("JOB_INFO.xlsx")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (14) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df2.head(10)
# Out:
#     ENO   Age Dept  Gender Skill  WorkingYear  Salary  TrainedYear  \
# 0  E001  29.0   HR  Female   SQL          3.0     825          3.0
# 1  E002  39.0   IT    Male  Java          7.0    1450          7.0
# 2  E003   NaN   IT    Male   SQL          6.0    1236          NaN
# 3  E004  38.0   HR  Female    C#          6.0    1324          5.0
# 4  E005  28.0   IT    Male     R          2.0     895          3.0
# 5  E006  36.0   MA    Male    C#          5.0     943          3.0
# 6  E007  27.0  NaN    Male   SQL          2.0    1154          5.0
# 7  E008  28.0   MA  Female     R          NaN    1356          6.0
# 8  E009  37.0   IT    Male  Java          7.0    1456          5.0
# 9  E010  37.0   IT     NaN    C#          6.0     892          3.0
#
#   OverseaProject
# 0             No
# 1            Yes
# 2            Yes
# 3             No
# 4             No
# 5             No
# 6             No
# 7            Yes
# 8             No
# 9             No

# %%
df2.columns
# Out:
# Index(['ENO', 'Age', 'Dept', 'Gender', 'Skill', 'WorkingYear', 'Salary',
#        'TrainedYear', 'OverseaProject'],
#       dtype='object')

# %%
df2.describe()
# Out:
#              Age  WorkingYear       Salary  TrainedYear
# count  44.000000    45.000000    46.000000    43.000000
# mean   28.977273     4.133333  1143.847826     3.976744
# std     4.406595     1.739906   238.132360     1.318158
# min    22.000000     1.000000   766.000000     2.000000
# 25%    26.750000     3.000000   894.250000     3.000000
# 50%    28.500000     4.000000  1216.500000     4.000000
# 75%    31.000000     5.000000  1347.250000     5.000000
# max    39.000000     7.000000  1457.000000     7.000000

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46 entries, 0 to 45
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   ENO             46 non-null     object
#  1   Age             44 non-null     float64
#  2   Dept            44 non-null     object
#  3   Gender          45 non-null     object
#  4   Skill           46 non-null     object
#  5   WorkingYear     45 non-null     float64
#  6   Salary          46 non-null     int64
#  7   TrainedYear     43 non-null     float64
#  8   OverseaProject  46 non-null     object
# dtypes: float64(3), int64(1), object(5)
# memory usage: 3.4+ KB

# %%
z = df2["Age"].to_numpy()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
fig = plt.figure()
fig.patch.set_facecolor('xkcd:mint green')
sns.histplot(data=df2, x='Age', bins = int(len(z)/2))
plt.title("Histogram of Age")
# Out:
# Text(0.5, 1.0, 'Histogram of Age')

# %%
fig = plt.figure()
fig.patch.set_facecolor('xkcd:mint green')
sns.barplot(data=df2, x='TrainedYear', y = "Salary")
plt.show()

# %%
fig = plt.figure()
fig.patch.set_facecolor('xkcd:mint green')
sns.boxplot(x=df2['Salary'])
plt.show()

# %%
fig = plt.figure()
fig.patch.set_facecolor('xkcd:mint green')
sns.boxplot(data=df2, x="Gender", y="Salary")
plt.show()

# %%
df2.head(10)
# Out:
#     ENO   Age Dept  Gender Skill  WorkingYear  Salary  TrainedYear  \
# 0  E001  29.0   HR  Female   SQL          3.0     825          3.0
# 1  E002  39.0   IT    Male  Java          7.0    1450          7.0
# 2  E003   NaN   IT    Male   SQL          6.0    1236          NaN
# 3  E004  38.0   HR  Female    C#          6.0    1324          5.0
# 4  E005  28.0   IT    Male     R          2.0     895          3.0
# 5  E006  36.0   MA    Male    C#          5.0     943          3.0
# 6  E007  27.0  NaN    Male   SQL          2.0    1154          5.0
# 7  E008  28.0   MA  Female     R          NaN    1356          6.0
# 8  E009  37.0   IT    Male  Java          7.0    1456          5.0
# 9  E010  37.0   IT     NaN    C#          6.0     892          3.0
#
#   OverseaProject
# 0             No
# 1            Yes
# 2            Yes
# 3             No
# 4             No
# 5             No
# 6             No
# 7            Yes
# 8             No
# 9             No

# %%
fig = plt.figure()
fig.patch.set_facecolor('xkcd:mint green')
sns.barplot(data=df2, x='Age', y = "Salary")
plt.show()

# %%
df2.corr()
# Out:
#                   Age  WorkingYear    Salary  TrainedYear
# Age          1.000000     0.787217  0.428102     0.397530
# WorkingYear  0.787217     1.000000  0.566201     0.469764
# Salary       0.428102     0.566201  1.000000     0.910077
# TrainedYear  0.397530     0.469764  0.910077     1.000000

# %%
fig = plt.figure()
fig.patch.set_facecolor('xkcd:mint green')
sns.scatterplot(data=df2, x='TrainedYear', y='Salary')
plt.show()

# %%
pivot_table = df2.pivot_table(values='Salary', index='Dept', columns='Gender')

# %%
fig = plt.figure()
fig.patch.set_facecolor('xkcd:mint green')
sns.heatmap(df2.corr(), cmap='YlGnBu')
# Out:
# <AxesSubplot:>

# %%
fig = plt.figure()
fig.patch.set_facecolor('xkcd:mint green')
sns.heatmap(pivot_table, cmap='YlGnBu')
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Dept'>

# %%
from scipy.stats import spearmanr
corr, p_value = spearmanr(df2["Salary"], df2["TrainedYear"])
print("Spearman correlation coefficient: ", corr, p_value)
# Out:
# Spearman correlation coefficient:  nan nan

# %%
df1.head()
del df1["Unnamed: 10"]
df1
# Out:
#         Toan   Van  Anh    Ly   Hoa  Sinh   Su   Dia  GDCD  KhoiA  KhoiB  \
# SoBD
# 1        3.0  3.75  3.0   NaN   NaN   NaN  3.0  6.50  8.25    NaN    NaN
# 2        8.8  7.50  9.0   NaN   NaN   NaN  6.0  9.00  8.25    NaN    NaN
# 3        6.0  5.50  4.0  5.75  5.50  5.00  NaN   NaN   NaN  17.25  16.50
# 4        3.4  5.75  2.6   NaN   NaN   NaN  3.5  4.75  7.25    NaN    NaN
# 5        3.8  6.75  3.0   NaN   NaN   NaN  3.5  6.25  8.00    NaN    NaN
# ...      ...   ...  ...   ...   ...   ...  ...   ...   ...    ...    ...
# 744392   4.6  4.50  6.0  3.75  3.00  3.25  NaN   NaN   NaN  11.35  10.85
# 744393   7.0  6.00  5.0  5.25  5.50  4.00  NaN   NaN   NaN  17.75  16.50
# 744394   5.2  3.50  4.0  6.25  5.50  2.25  NaN   NaN   NaN  16.95  12.95
# 744395   7.8  4.50  5.4  7.50  6.25  3.00  NaN   NaN   NaN  21.55  17.05
# 744396   5.8  3.50  3.0  6.25  4.75  3.25  NaN   NaN   NaN  16.80  13.80
#
#         KhoiC  KhoiD  KhoiA1  Ma Tinh          Ten Tinh Vung mien
# SoBD
# ...

# %%
df1.describe()[["Toan", "Van", "Anh"]]
# Out:
#                 Toan            Van            Anh
# count  741024.000000  728309.000000  659998.000000
# mean        4.884162       5.443449       3.933543
# std         1.440636       1.447770       1.567942
# min         0.000000       0.000000       0.000000
# 25%         3.800000       4.500000       2.800000
# 50%         5.000000       5.500000       3.600000
# 75%         6.000000       6.500000       4.600000
# max        10.000000       9.750000      10.000000

# %%
df1[df1.columns[:9]].describe().loc[['mean', 'std']]
# Out:
#           Toan       Van       Anh        Ly       Hoa      Sinh        Su  \
# mean  4.884162  5.443449  3.933543  4.961179  4.864391  4.561249  3.805371
# std   1.440636  1.447770  1.567942  1.531097  1.523851  1.244402  1.241262
#
#            Dia      GDCD
# mean  5.483495  7.157468
# std   1.257440  1.233368

# %%
z = df1[df1.columns[:9]].describe().loc[["min", "25%","50%","75%","max"]][["Toan", "Van", "Anh"]]
z
# Out:
#      Toan   Van   Anh
# min   0.0  0.00   0.0
# 25%   3.8  4.50   2.8
# 50%   5.0  5.50   3.6
# 75%   6.0  6.50   4.6
# max  10.0  9.75  10.0

# %%
df1.groupby(df1.columns[-2])[df1.columns[:9]].describe()["Van"]
# Out:
#                     count      mean       std   min   25%   50%   75%   max
# Ten Tinh
#  BInh Duong       11028.0  5.644745  1.114282  0.00  5.00  5.75  6.50  9.00
#  BInh Thuan       11569.0  6.054283  1.156058  0.00  5.50  6.00  6.75  9.25
#  Ba Ria Vung Tau  11670.0  5.048650  1.293025  0.00  4.25  5.00  6.00  9.00
#  Bac Giang        19350.0  5.620116  1.360498  0.00  4.75  5.75  6.50  9.25
#  Bac Kan           2827.0  5.820039  1.634524  0.75  4.50  6.00  7.00  9.50
#  Bac Lieu          5285.0  6.200237  1.171901  0.50  5.50  6.25  7.00  9.25
#  Bac Ninh         14620.0  5.348718  1.615666  0.00  4.00  5.25  6.50  9.50
#  Ben Tre          11626.0  5.299480  1.248422  0.75  4.50  5.25  6.25  9.00
#  Binh Dinh        17521.0  5.184650  1.386622  0.50  4.25  5.25  6.25  9.50
#  Binh Phuoc       10072.0  5.227164  1.362637  0.00  4.50  5.25  6.00  9.25
#  Ca Mau            9138.0  5.563526  1.350975  0.25  4.75  5.50  6.50  9.50
# ...

# %%
fig, ax = plt.subplots(ncols = 3, nrows = 3, figsize = (75,50))
fig.patch.set_facecolor('xkcd:mint green')
z=0
for i in range(9):
    if i >= 3 and i <6:
        z=1
        i-=3
    elif i >= 6:
        z=2
        i-=6

    ax[z][i].hist(df1[df1.columns[i]], width = 0.7)
    ax[z][i].set_xlabel('Diem '+df1.columns[i], fontsize = 50)
    ax[z][i].set_ylabel('So luong', fontsize = 50)
plt.show()
